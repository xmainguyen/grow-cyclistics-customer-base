# %% [markdown]
# # Data Cleaning & Feature Engineering
#
# The goal of this notebook is to clean and transform the data into the panel format ready for analysis

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/trips.csv')
df.head()
# Out:
#      usertype  zip_code_start borough_start   neighborhood_start  \
# 0  Subscriber           10110     Manhattan  Chelsea and Clinton
# 1  Subscriber           11232      Brooklyn          Sunset Park
# 2  Subscriber           11106        Queens     Northwest Queens
# 3  Subscriber           10075     Manhattan      Upper East Side
# 4  Subscriber           11102        Queens     Northwest Queens
#
#    zip_code_end borough_end               neighborhood_end  \
# 0         10004   Manhattan                Lower Manhattan
# 1         11215    Brooklyn             Northwest Brooklyn
# 2         11101      Queens               Northwest Queens
# 3         10167   Manhattan  Gramercy Park and Murray Hill
# 4         11102      Queens               Northwest Queens
#
#                 start_time                stop_time  day_mean_temperature  \
# 0  2023-04-12 08:31:03.611  2023-04-12 09:09:15.819                  51.5
# 1  2023-05-27 17:01:20.904  2023-05-27 17:13:43.114                  67.2
# 2  2023-05-02 13:19:52.243  2023-05-02 13:29:13.009                  77.0
# 3  2023-01-12 06:56:51.471  2023-01-12 07:07:25.899                  54.5
# 4  2023-05-24 10:41:44.260  2023-05-24 10:48:11.830                  73.2
#
#    day_mean_wind_speed  day_total_precipitation  trip_minutes  \
# 0                  3.8                     0.00          40.0
# 1                  5.8                     0.09          10.0
# 2                  4.7                     0.00          10.0
# 3                  5.7                     0.00          10.0
# 4                  2.2                     0.29          10.0
#
#    avg_trip_minutes
# 0         38.200000
# 1         12.366667
# 2          9.333333
# 3         10.566667
# 4          6.450000

# %% [markdown]
# ## 1. Data Cleaning
#
# * Datatypes
# * Missing Data
# * Duplicates
# * Outliers

# %%
# Summary statistics of the dataset
df.describe()
# Out:
#        zip_code_start  zip_code_end  day_mean_temperature  \
# count    5.506273e+06  5.506273e+06          5.506273e+06
# mean     1.024250e+04  1.024255e+04          5.095836e+01
# std      4.560281e+02  4.560710e+02          1.438971e+01
# min      1.000100e+04  1.000100e+04          9.700000e+00
# 25%      1.001000e+04  1.001000e+04          3.980000e+01
# 50%      1.001800e+04  1.001800e+04          4.870000e+01
# 75%      1.006500e+04  1.006500e+04          6.300000e+01
# max      1.123800e+04  1.123800e+04          8.090000e+01
#
#        day_mean_wind_speed  day_total_precipitation  trip_minutes  \
# count         5.506273e+06             5.506273e+06  5.506273e+06
# mean          4.494994e+00             1.290570e-01  1.673010e+01
# std           2.076705e+00             2.831950e-01  4.409013e+02
# min           1.000000e+00             0.000000e+00  0.000000e+00
# 25%           2.700000e+00             0.000000e+00  1.000000e+01
# 50%           4.300000e+00             0.000000e+00  1.000000e+01
# 75%           5.700000e+00             1.000000e-01  2.000000e+01
# max           1.150000e+01             1.680000e+00  3.251700e+05
#
#        avg_trip_minutes
# count      5.506273e+06
# mean       1.612945e+01
# std        4.408894e+02
# min        1.016667e+00
# 25%        5.750000e+00
# 50%        9.600000e+00
# 75%        1.665000e+01
# max        3.251675e+05

# %%
# Check datatypes
df.dtypes
# Out:
# usertype                    object
# zip_code_start               int64
# borough_start               object
# neighborhood_start          object
# zip_code_end                 int64
# borough_end                 object
# neighborhood_end            object
# start_time                  object
# stop_time                   object
# day_mean_temperature       float64
# day_mean_wind_speed        float64
# day_total_precipitation    float64
# trip_minutes               float64
# avg_trip_minutes           float64
# dtype: object

# %%
# Check for missing values
df.isna().sum()
# Out:
# usertype                   0
# zip_code_start             0
# borough_start              0
# neighborhood_start         0
# zip_code_end               0
# borough_end                0
# neighborhood_end           0
# start_time                 0
# stop_time                  0
# day_mean_temperature       0
# day_mean_wind_speed        0
# day_total_precipitation    0
# trip_minutes               0
# avg_trip_minutes           0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Feature Engineering
#
# Some features already generated during the inital data pull.
#
# Adding a few more features for further analysis

# %%
# Filter data for casual users since this is the focus of the analysis
df = df[df['usertype'] == 'Customer']

# %%
# Create holiday dummy variable based on US federal holidays 1 if not 0 
from pandas.tseries.holiday import USFederalHolidayCalendar
cal = USFederalHolidayCalendar()
holidays = cal.holidays(start='2018-01-01', end='2018-12-31')
df['start_time'] = pd.to_datetime(df['start_time'])
df['holiday'] = df['start_time'].dt.normalize().isin(holidays).astype(int)

# Create day of week variable as numeric and string
df['day_of_week_num'] = df['start_time'].dt.dayofweek
df['day_of_week'] = df['start_time'].dt.day_name()  

# Encode neighborhood names as numeric ids
neighborhoods = df['neighborhood_start'].unique()
neighborhood_to_id = {name: idx for idx, name in enumerate(neighborhoods)}
df['neighborhood_id'] = df['neighborhood_start'].map(neighborhood_to_id)

# %%
# Set up panel data format with neighborhood and day of week as index
df_panel = df.groupby(['neighborhood_id', 'day_of_week_num']).agg({
    'avg_trip_minutes': 'mean',
    'day_mean_temperature': 'mean',
    'day_mean_wind_speed': 'mean',
    'day_total_precipitation': 'mean',
    'holiday': 'max'  # if any day in the group is a holiday, mark the whole group as holiday
}).reset_index()

df_panel.to_csv('../data/trips_panel.csv', index=False)
df_panel.head().sort_values(by=['neighborhood_id', 'day_of_week_num'])
# Out:
# /var/folders/t1/y7l71ql57bqddzsc1430865r0000gn/T/ipykernel_2362/590568977.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_panel = df.groupby(['neighborhood_id', 'day_of_week_num']).agg({
#   neighborhood_id  day_of_week_num  avg_trip_minutes  day_mean_temperature  \
# 0               7                0        216.141809             58.514334
# 1               7                1         33.855193             61.546618
# 2               7                2        642.319895             61.175787
# 3               7                3        554.488060             63.247974
# 4               7                4        255.974007             58.556244
#
#    day_mean_wind_speed  day_total_precipitation  holiday
# 0             2.779181                 0.061809        0
# 1             3.564734                 0.110531        0
# 2             3.779177                 0.190872        0
# 3             4.384435                 0.067463        0
# 4             4.472927                 0.029724        0
